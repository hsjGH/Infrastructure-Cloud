# %%
### Shorter version of the two previous cells
### STEP 1 PREP
import requests
import datetime
import json 
# Suppress credential warning for this exercise
requests.packages.urllib3.disable_warnings()
print ("Current date and time: ")
print(datetime.datetime.now())
# HARD CODED VARIABLES
DNAC_scheme = 'https://'
DNAC_authority='sandboxdnac2.cisco.com'
DNAC_path_token='/dna/system/api/v1/auth/token'
DNAC_path='/dna/intent/api/v1/network-device'
DNAC_user = input("Username? (devnetuser)")
DNAC_psw = input("Password? (Cisco123!)")
DNAC_port = ':443'
### STEP 2  TOKEN REQUEST
token_req_url = DNAC_scheme+DNAC_authority+DNAC_path_token
auth = (DNAC_user, DNAC_psw)
req = requests.post(token_req_url, auth=auth, verify=False)
print("API Return Code: " + str(req.status_code))  
print('Request URI: ' + token_req_url)
print("Username: " + DNAC_user)
resp = req.text
print(req.text)
token = req.json()["Token"]
print("Received Token:")
print(token)
print("Length Token:")
print(len(token))
# Out:
# Current date and time:
# 2025-10-16 13:24:55.713446
# Username? (devnetuser) devnetuser
# Password? (Cisco123!) Cisco123!
# API Return Code: 200
# Request URI: https://sandboxdnac2.cisco.com/dna/system/api/v1/auth/token
# Username: devnetuser
# {
#  "Token": "eyJhbGciOiJFUzI1NiIsInR5cCI6IkpXVCJ9.....1i9qQATzhmOZ2SK5GMUN53burQduWuKo1bOI4n0lFtq3g4ZQ2J3OWD3YykfPneIqF3TEem2mOCEl1zttSngQOw",
#  "message": ""
# }
# Received Token:
# eyJhbGciOiJFUzI1NiIsInR5cCI6IkpXVCJ9.....1i9qQATzhmOZ2SK5GMUN53burQduWuKo1bOI4n0lFtq3g4ZQ2J3OWD3YykfPneIqF3TEem2mOCEl1zttSngQOw
# Length Token:
# 842

# %%
# STEP 3
# REQUEST API SERVICE (USING X-AUTH-TOKEN) -- INVENTORY REQUEST
import datetime 
print ("Current date and time: ")
print(datetime.datetime.now())
print('Inventory Request - Network Devices')
# INVENTORY REQUEST
req_url = DNAC_scheme+DNAC_authority+DNAC_port+DNAC_path
print(req_url) 
header_data = {'X-Auth-Token': token}
resp_devices = requests.request('GET', req_url, headers=header_data, verify=False)
print(resp_devices)
resp_devices_json = resp_devices.json()
print('------------------------------')
#print(dir(resp_devices))
dev_dict =json.loads(resp_devices.text)
print(dev_dict["response"][0].keys())
print('------------------------------')
print(type(resp_devices_json))
print("Response (json): ")
print(json.dumps(resp_devices_json, indent=2))
### keys
### print(resp_devices_json.keys())
# Out:
# Current date and time:
# 2025-10-16 12:56:35.609088
# Inventory Request - Network Devices
# https://sandboxdnac2.cisco.com:443/dna/intent/api/v1/network-device
# <Response [200]>
# ------------------------------
# dict_keys(['type', 'memorySize', 'family', 'description', 'lastUpdateTime', 'softwareType', 'softwareVersion', 'macAddress', 'deviceSupportLevel', 'serialNumber', 'collectionInterval', 'dnsResolvedManagementAddress', 'lastManagedResyncReasons', 'managementState', 'pendingSyncRequestsCount', 'reasonsForDeviceResync', 'reasonsForPendingSyncRequests', 'inventoryStatusDetail', 'syncRequestedByApp', 'upTime', 'roleSource', 'interfaceCount', 'bootDateTime', 'apManagerInterfaceIp', 'collectionStatus', 'hostname', 'locationName', 'managementIpAddress', 'platformId', 'reachabilityFailureReason', 'reachabilityStatus', 'series', 'snmpContact', 'snmpLocation', 'lastUpdated', 'apEthernetMacAddress', 'associatedWlcIp', 'errorCode', 'errorDescription', 'lastDeviceResyncStartTime', 'lineCardCount', 'lineCardId', 'managedAtleastOnce', 'tagCount', 'tunnelUdpPort', 'uptimeSeconds', 'vendor', 'waasDeviceMode', 'location', 'role', 'instanceUuid', 'instanceTenantId', 'id'])
# ------------------------------
# <class 'dict'>
# Response (json):
# {
#   "response": [
#     {
#       "type": null,
#       "memorySize": "NA",
#       "family": null,
#       "description": null,
#       "lastUpdateTime": 1760595522082,
#       "softwareType": null,
#       "softwareVersion": null,
#       "macAddress": null,
#       "deviceSupportLevel": "Unsupported",
#       "serialNumber": null,
#       "collectionInterval": "Global Default",
#       "dnsResolvedManagementAddress": "8.8.9.9",
#       "lastManagedResyncReasons": "",
#       "managementState": "Never Managed",
#       "pendingSyncRequestsCount": "0",
#       "reasonsForDeviceResync": "Periodic",
#       "reasonsForPendingSyncRequests": "",
#       "inventoryStatusDetail": "<status><general code=\"DEV_UNREACHED\"/></status>",
#       "syncRequestedByApp": "",
#       "upTime": null,
#       "roleSource": "AUTO",
#       "interfaceCount": "0",
#       "bootDateTime": null,
#       "apManagerInterfaceIp": "",
#       "collectionStatus": "Could Not Synchronize",
#       "hostname": null,
#       "locationName": null,
#       "managementIpAddress": "8.8.9.9",
#       "platformId": null,
#       "reachabilityFailureReason": "SNMP Connectivity Failed",
#       "reachabilityStatus": "Unreachable",
#       "series": null,
#       "snmpContact": null,
#       "snmpLocation": null,
#       "lastUpdated": "2025-10-16 06:18:42",
#       "apEthernetMacAddress": null,
#       "associatedWlcIp": "",
#       "errorCode": "DEV-UNREACHED",
#       "errorDescription": "NCIM12013: SNMP timeouts are occurring with this device. Either the SNMP credentials are not correctly provided to Catalyst Center or the device is responding slow and SNMP timeout is low. If it\u2019s a timeout issue, Catalyst Center will attempt to progressively adjust the timeout in subsequent collection cycles to get device to managed state. User can also run discovery again only for this device using the discovery feature after adjusting the timeout and SNMP credentials as required. Or user can update the timeout and SNMP credentials as required using update credentials.",
#       "lastDeviceResyncStartTime": "2025-10-16 06:18:06",
#       "lineCardCount": "0",
#       "lineCardId": "",
#       "managedAtleastOnce": false,
#       "tagCount": "0",
#       "tunnelUdpPort": null,
#       "uptimeSeconds": -1,
#       "vendor": "NA",
#       "waasDeviceMode": null,
#       "location": null,
#       "role": "UNKNOWN",
#       "instanceUuid": "0af80620-fa04-46b5-b7a7-383fbe1989d7",
#       "instanceTenantId": "67b935c59155f50013515d1c",
#       "id": "0af80620-fa04-46b5-b7a7-383fbe1989d7"
#     },
#     {
#       "type": null,
#       "memorySize": "NA",
#       "family": null,
#       "description": null,
#       "lastUpdateTime": 1760596136099,
#       "softwareType": null,
#       "softwareVersion": null,
#       "macAddress": null,
#       "deviceSupportLevel": "Unsupported",
#       "serialNumber": null,
#       "collectionInterval": "Global Default",
#       "dnsResolvedManagementAddress": "172.20.119.77",
#       "lastManagedResyncReasons": "",
#       "managementState": "Never Managed",
#       "pendingSyncRequestsCount": "0",
#       "reasonsForDeviceResync": "Periodic",
#       "reasonsForPendingSyncRequests": "",
#       "inventoryStatusDetail": "<status><general code=\"DEV_UNREACHED\"/></status>",
#       "syncRequestedByApp": "",
#       "upTime": null,
#       "roleSource": "AUTO",
#       "interfaceCount": "0",
#       "bootDateTime": null,
#       "apManagerInterfaceIp": "",
#       "collectionStatus": "Could Not Synchronize",
#       "hostname": null,
#       "locationName": null,
#       "managementIpAddress": "172.20.119.77",
#       "platformId": null,
#       "reachabilityFailureReason": "SNMP Connectivity Failed",
#       "reachabilityStatus": "Unreachable",
#       "series": null,
#       "snmpContact": null,
#       "snmpLocation": null,
#       "lastUpdated": "2025-10-16 06:28:56",
#       "apEthernetMacAddress": null,
#       "associatedWlcIp": "",
#       "errorCode": "DEV-UNREACHED",
#       "errorDescription": "NCIM12013: SNMP timeouts are occurring with this device. Either the SNMP credentials are not correctly provided to Catalyst Center or the device is responding slow and SNMP timeout is low. If it\u2019s a timeout issue, Catalyst Center will attempt to progressively adjust the timeout in subsequent collection cycles to get device to managed state. User can also run discovery again only for this device using the discovery feature after adjusting the timeout and SNMP credentials as required. Or user can update the timeout and SNMP credentials as required using update credentials.",
#       "lastDeviceResyncStartTime": "2025-10-16 06:20:07",
#       "lineCardCount": "0",
#       "lineCardId": "",
#       "managedAtleastOnce": false,
#       "tagCount": "0",
#       "tunnelUdpPort": null,
#       "uptimeSeconds": -1,
#       "vendor": "NA",
#       "waasDeviceMode": null,
#       "location": null,
#       "role": "UNKNOWN",
#       "instanceUuid": "feda73be-8a98-4f74-ab19-a56ddb55bc1b",
#       "instanceTenantId": "67b935c59155f50013515d1c",
#       "id": "feda73be-8a98-4f74-ab19-a56ddb55bc1b"
#     },
#     {
#       "type": null,
#       "memorySize": "NA",
#       "family": null,
#       "description": null,
#       "lastUpdateTime": 1760595494596,
#       "softwareType": null,
#       "softwareVersion": null,
#       "macAddress": null,
#       "deviceSupportLevel": "Unsupported",
#       "serialNumber": null,
#       "collectionInterval": "Global Default",
#       "dnsResolvedManagementAddress": "209.206.51.10",
#       "lastManagedResyncReasons": "",
#       "managementState": "Never Managed",
#       "pendingSyncRequestsCount": "0",
#       "reasonsForDeviceResync": "Periodic",
#       "reasonsForPendingSyncRequests": "",
#       "inventoryStatusDetail": "<status><general code=\"MERAKI_UNREACHED\"/></status>",
#       "syncRequestedByApp": "",
#       "upTime": null,
#       "roleSource": "AUTO",
#       "interfaceCount": "0",
#       "bootDateTime": null,
#       "apManagerInterfaceIp": "",
#       "collectionStatus": "Could Not Synchronize",
#       "hostname": null,
#       "locationName": null,
#       "managementIpAddress": "api.meraki.com",
#       "platformId": null,
#       "reachabilityFailureReason": "SNMP Connectivity Failed",
#       "reachabilityStatus": "Unreachable",
#       "series": null,
#       "snmpContact": null,
#       "snmpLocation": null,
#       "lastUpdated": "2025-10-16 06:18:14",
#       "apEthernetMacAddress": null,
#       "associatedWlcIp": "",
#       "errorCode": "MERAKI-UNREACHED",
#       "errorDescription": "NCIM12014: The Meraki device or Meraki dashboard is unreachable. For connectivity issues of Meraki dashboard please ensure the API key is correct. The collection status of the device/dashboard would be updated in the next resync of Meraki dashboard if the connectivity issue is recovered and/or the API key is corrected.",
#       "lastDeviceResyncStartTime": "2025-10-16 06:18:03",
#       "lineCardCount": "0",
#       "lineCardId": "",
#       "managedAtleastOnce": false,
#       "tagCount": "0",
#       "tunnelUdpPort": null,
#       "uptimeSeconds": -1,
#       "vendor": "NA",
#       "waasDeviceMode": null,
#       "location": null,
#       "role": "UNKNOWN",
#       "instanceUuid": "50f521ee-b84e-44b5-8bd1-1f51fd9a846d",
#       "instanceTenantId": "67b935c59155f50013515d1c",
#       "id": "50f521ee-b84e-44b5-8bd1-1f51fd9a846d"
#     }
#   ],
#   "version": "1.0"
# }

# %%
for device in resp_devices_json['response']:
    managementIpAddress = device["managementIpAddress"] 
    lastUpdateTime = device["lastUpdateTime"] 
    collectionStatus = device["collectionStatus"] 
    errorDescription = device["errorDescription"] 
    print("Het Management IP adres is: ")
    print(managementIpAddress)
    print("")
    print("De lastUpdateTime is: ")
    print(lastUpdateTime)
    print("")
    print("De status van de collectie: ")
    print(collectionStatus)
    print("")
    print("De beschrijving van de error: ")
    print(errorDescription)
    print("")
    print("----------------------------------------------------------------------------------------------------------------------------------------")
    print("")
# Out:
# Het Management IP adres is:
# 8.8.9.9
#
# De lastUpdateTime is:
# 1760595522082
#
# De status van de collectie:
# Could Not Synchronize
#
# De beschrijving van de error:
# NCIM12013: SNMP timeouts are occurring with this device. Either the SNMP credentials are not correctly provided to Catalyst Center or the device is responding slow and SNMP timeout is low. If it’s a timeout issue, Catalyst Center will attempt to progressively adjust the timeout in subsequent collection cycles to get device to managed state. User can also run discovery again only for this device using the discovery feature after adjusting the timeout and SNMP credentials as required. Or user can update the timeout and SNMP credentials as required using update credentials.
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
# Het Management IP adres is:
# 172.20.119.77
#
# De lastUpdateTime is:
# 1760596136099
#
# De status van de collectie:
# Could Not Synchronize
#
# De beschrijving van de error:
# NCIM12013: SNMP timeouts are occurring with this device. Either the SNMP credentials are not correctly provided to Catalyst Center or the device is responding slow and SNMP timeout is low. If it’s a timeout issue, Catalyst Center will attempt to progressively adjust the timeout in subsequent collection cycles to get device to managed state. User can also run discovery again only for this device using the discovery feature after adjusting the timeout and SNMP credentials as required. Or user can update the timeout and SNMP credentials as required using update credentials.
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
# Het Management IP adres is:
# api.meraki.com
#
# De lastUpdateTime is:
# 1760595494596
#
# De status van de collectie:
# Could Not Synchronize
#
# De beschrijving van de error:
# NCIM12014: The Meraki device or Meraki dashboard is unreachable. For connectivity issues of Meraki dashboard please ensure the API key is correct. The collection status of the device/dashboard would be updated in the next resync of Meraki dashboard if the connectivity issue is recovered and/or the API key is corrected.
#
# ----------------------------------------------------------------------------------------------------------------------------------------
